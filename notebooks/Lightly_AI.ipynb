# %% [markdown]
# # Object Detection with Ultralytics' YOLO
#
# This tutorial demonstrates how to pretrain a YOLO model using LightlyTrain and then fine-tune it for object detection using the `ultralytics` framework. To this end, we will first pretrain on a [25k image subset](https://github.com/giddyyupp/coco-minitrain) of the [COCO dataset](https://cocodataset.org/#home) (only the images, no labels!), and subsequently finetune on the labeled [PASCAL VOC dataset](http://host.robots.ox.ac.uk/pascal/VOC/).
#
# ## Install Dependencies
#
# Install the required packages:
#
# - `lightly-train` for pretraining, with support for `ultralytics`' YOLO models
# - [`supervision`](https://github.com/roboflow/supervision) to visualize some of the annotated pictures

# %%
# !uv pip install "lightly-train[ultralytics]" "supervision==0.25.1" ipywidgets

# %% [markdown]
# > **Important**: LightlyTrain is officially supported on
# > - Linux: CPU or CUDA
# > - MacOS: CPU only
# > - Windows (experimental): CPU or CUDA
# >
# > We are planning to support MPS for MacOS.
# >
# > Check the [installation instructions](https://docs.lightly.ai/train/stable/installation.html) for more details on installation.

# %% [markdown]
# ## Pretraining on COCO-minitrain
# We can download the COCO-minitrain dataset (25k images) directly from HuggingFace...

# %%
# !wget https://huggingface.co/datasets/bryanbocao/coco_minitrain/resolve/main/coco_minitrain_25k.zip

# %% [markdown]
# ... unzip it...

# %%
# !unzip coco_minitrain_25k.zip

# %% [markdown]
# ... and since Lightly**Train** does not require any labels, we can also confidently delete all the labels:

# %%
# !rm -rf coco_minitrain_25k/labels

# %% [markdown]
# With the dataset ready, we can now start the pretraining. Pretraining with Lightly**Train** could not be easier, you just pass the following parameters:
#  - `out`: you simply state where you want your logs and exported model to go to
#  - `model`: the model that you want to train, e.g. `yolo11s` from Ultralytics
#  - `data`: the path to a folder with images
#
#  Your data is simply assumed to be an arbitrarily nested folder; LightlyTrain with find all images on its own and since there are no labels required there is no danger of ever using false labels! 🕵️‍♂️
#
# It is highly recommended to run this pretraining on a GPU, expect about 60min of training time on Colab's free version!

# %%
out = r"C:\Users\jordan\Documents\GitHub\CoralNet-Toolbox\data\cac\PUS\Experiment_2\pretrained_from_pretrained_default"

import os 
os.makedirs(out, exist_ok=True)

# %%
import glob

path = "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\train"
data = glob.glob(f"{path}\**\*.jpg",
                 recursive=True)

len(data)
# Out:
# 646

# %%
import lightly_train

lightly_train.pretrain(
    out=f"{out}/scratch",  # Output directory.
    model="ultralytics/yolo11n.pt",  # Pass the YOLO model (use .yaml ending to start with random weights).
    data=data,  # Path to a directory with training images.
    overwrite=True,  # A overwriting so that this cell can be re-run.
    epochs=200,  # Number of training epochs.
)
# Out:
# Args: {
#     "accelerator": "auto",
#     "batch_size": 128,
#     "callbacks": null,
#     "checkpoint": null,
#     "data": [
#         "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\train\\images\\0_db6a96e8.jpg",
#         "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\train\\images\\100519_2125b236.jpg",
#         "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\train\\images\\10249_b8b43c82.jpg",
#         "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\train\\images\\10279_e9d302b4.jpg",
#         "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\train\\images\\102887_6fe6d124.jpg",
#         "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\train\\images\\103816_4a4c2654.jpg",
#         "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\train\\images\\10399_b93a4f38.jpg",
#         "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\train\\images\\104025_5c34ced9.jpg",
#         "... 637 more values",
#         "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\train\\images\\9950_221fe7c3.jpg"
#     ],
#     "devices": "auto",
#     "embed_dim": null,
#     "epochs": 200,
#     "float32_matmul_precision": "auto",
#     "loader_args": null,
#     "loggers": null,
#     "method": "distillation",
#     "method_args": null,
#     "model": "ultralytics/yolo11n.pt",
#     "model_args": null,
#     "num_nodes": 1,
#     "num_workers": "auto",
#     "optim": "auto",
#     "optim_args": null,
#     "out": "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\Experiment_2\\pretrained_from_pretrained_default/scratch",
#     "overwrite": true,
#     "precision": "auto",
#     "resume": null,
#     "resume_interrupted": false,
#     "seed": 0,
#     "strategy": "auto",
#     "trainer_args": null,
#     "transform_args": null
# }
# Using output directory 'C:\Users\jordan\Documents\GitHub\CoralNet-Toolbox\data\cac\PUS\Experiment_2\pretrained_from_pretrained_default\scratch'.
# Seed set to 0
# Enabling gradients for parameter 'model.model.0.conv.weight'
# Enabling gradients for parameter 'model.model.0.bn.weight'
# Enabling gradients for parameter 'model.model.0.bn.bias'
# Enabling gradients for parameter 'model.model.1.conv.weight'
# Enabling gradients for parameter 'model.model.1.bn.weight'
# Enabling gradients for parameter 'model.model.1.bn.bias'
# Enabling gradients for parameter 'model.model.2.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.2.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.2.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.2.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.2.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.2.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.2.m.0.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.2.m.0.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.2.m.0.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.2.m.0.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.2.m.0.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.2.m.0.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.3.conv.weight'
# Enabling gradients for parameter 'model.model.3.bn.weight'
# Enabling gradients for parameter 'model.model.3.bn.bias'
# Enabling gradients for parameter 'model.model.4.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.4.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.4.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.4.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.4.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.4.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.4.m.0.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.4.m.0.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.4.m.0.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.4.m.0.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.4.m.0.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.4.m.0.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.5.conv.weight'
# Enabling gradients for parameter 'model.model.5.bn.weight'
# Enabling gradients for parameter 'model.model.5.bn.bias'
# Enabling gradients for parameter 'model.model.6.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.6.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.6.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.6.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.6.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.6.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.6.m.0.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.6.m.0.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.6.m.0.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.6.m.0.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.6.m.0.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.6.m.0.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.6.m.0.cv3.conv.weight'
# Enabling gradients for parameter 'model.model.6.m.0.cv3.bn.weight'
# Enabling gradients for parameter 'model.model.6.m.0.cv3.bn.bias'
# Enabling gradients for parameter 'model.model.6.m.0.m.0.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.6.m.0.m.0.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.6.m.0.m.0.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.6.m.0.m.0.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.6.m.0.m.0.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.6.m.0.m.0.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.6.m.0.m.1.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.6.m.0.m.1.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.6.m.0.m.1.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.6.m.0.m.1.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.6.m.0.m.1.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.6.m.0.m.1.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.7.conv.weight'
# Enabling gradients for parameter 'model.model.7.bn.weight'
# Enabling gradients for parameter 'model.model.7.bn.bias'
# Enabling gradients for parameter 'model.model.8.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.8.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.8.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.8.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.8.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.8.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.8.m.0.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.8.m.0.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.8.m.0.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.8.m.0.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.8.m.0.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.8.m.0.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.8.m.0.cv3.conv.weight'
# Enabling gradients for parameter 'model.model.8.m.0.cv3.bn.weight'
# Enabling gradients for parameter 'model.model.8.m.0.cv3.bn.bias'
# Enabling gradients for parameter 'model.model.8.m.0.m.0.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.8.m.0.m.0.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.8.m.0.m.0.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.8.m.0.m.0.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.8.m.0.m.0.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.8.m.0.m.0.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.8.m.0.m.1.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.8.m.0.m.1.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.8.m.0.m.1.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.8.m.0.m.1.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.8.m.0.m.1.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.8.m.0.m.1.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.9.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.9.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.9.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.9.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.9.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.9.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.10.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.10.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.10.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.10.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.10.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.10.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.10.m.0.attn.qkv.conv.weight'
# Enabling gradients for parameter 'model.model.10.m.0.attn.qkv.bn.weight'
# Enabling gradients for parameter 'model.model.10.m.0.attn.qkv.bn.bias'
# Enabling gradients for parameter 'model.model.10.m.0.attn.proj.conv.weight'
# Enabling gradients for parameter 'model.model.10.m.0.attn.proj.bn.weight'
# Enabling gradients for parameter 'model.model.10.m.0.attn.proj.bn.bias'
# Enabling gradients for parameter 'model.model.10.m.0.attn.pe.conv.weight'
# Enabling gradients for parameter 'model.model.10.m.0.attn.pe.bn.weight'
# Enabling gradients for parameter 'model.model.10.m.0.attn.pe.bn.bias'
# Enabling gradients for parameter 'model.model.10.m.0.ffn.0.conv.weight'
# Enabling gradients for parameter 'model.model.10.m.0.ffn.0.bn.weight'
# Enabling gradients for parameter 'model.model.10.m.0.ffn.0.bn.bias'
# Enabling gradients for parameter 'model.model.10.m.0.ffn.1.conv.weight'
# Enabling gradients for parameter 'model.model.10.m.0.ffn.1.bn.weight'
# Enabling gradients for parameter 'model.model.10.m.0.ffn.1.bn.bias'
# Enabling gradients for parameter 'model.model.13.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.13.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.13.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.13.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.13.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.13.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.13.m.0.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.13.m.0.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.13.m.0.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.13.m.0.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.13.m.0.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.13.m.0.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.16.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.16.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.16.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.16.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.16.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.16.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.16.m.0.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.16.m.0.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.16.m.0.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.16.m.0.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.16.m.0.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.16.m.0.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.17.conv.weight'
# Enabling gradients for parameter 'model.model.17.bn.weight'
# Enabling gradients for parameter 'model.model.17.bn.bias'
# Enabling gradients for parameter 'model.model.19.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.19.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.19.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.19.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.19.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.19.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.19.m.0.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.19.m.0.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.19.m.0.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.19.m.0.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.19.m.0.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.19.m.0.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.20.conv.weight'
# Enabling gradients for parameter 'model.model.20.bn.weight'
# Enabling gradients for parameter 'model.model.20.bn.bias'
# Enabling gradients for parameter 'model.model.22.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.22.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.22.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.22.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.22.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.22.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.22.m.0.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.22.m.0.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.22.m.0.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.22.m.0.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.22.m.0.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.22.m.0.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.22.m.0.cv3.conv.weight'
# Enabling gradients for parameter 'model.model.22.m.0.cv3.bn.weight'
# Enabling gradients for parameter 'model.model.22.m.0.cv3.bn.bias'
# Enabling gradients for parameter 'model.model.22.m.0.m.0.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.22.m.0.m.0.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.22.m.0.m.0.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.22.m.0.m.0.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.22.m.0.m.0.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.22.m.0.m.0.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.22.m.0.m.1.cv1.conv.weight'
# Enabling gradients for parameter 'model.model.22.m.0.m.1.cv1.bn.weight'
# Enabling gradients for parameter 'model.model.22.m.0.m.1.cv1.bn.bias'
# Enabling gradients for parameter 'model.model.22.m.0.m.1.cv2.conv.weight'
# Enabling gradients for parameter 'model.model.22.m.0.m.1.cv2.bn.weight'
# Enabling gradients for parameter 'model.model.22.m.0.m.1.cv2.bn.bias'
# Enabling gradients for parameter 'model.model.23.cv2.0.0.conv.weight'
# Enabling gradients for parameter 'model.model.23.cv2.0.0.bn.weight'
# Enabling gradients for parameter 'model.model.23.cv2.0.0.bn.bias'
# Enabling gradients for parameter 'model.model.23.cv2.0.1.conv.weight'
# Enabling gradients for parameter 'model.model.23.cv2.0.1.bn.weight'
# Enabling gradients for parameter 'model.model.23.cv2.0.1.bn.bias'
# Enabling gradients for parameter 'model.model.23.cv2.0.2.weight'
# Enabling gradients for parameter 'model.model.23.cv2.0.2.bias'
# Enabling gradients for parameter 'model.model.23.cv2.1.0.conv.weight'
# Enabling gradients for parameter 'model.model.23.cv2.1.0.bn.weight'
# Enabling gradients for parameter 'model.model.23.cv2.1.0.bn.bias'
# Enabling gradients for parameter 'model.model.23.cv2.1.1.conv.weight'
# Enabling gradients for parameter 'model.model.23.cv2.1.1.bn.weight'
# Enabling gradients for parameter 'model.model.23.cv2.1.1.bn.bias'
# Enabling gradients for parameter 'model.model.23.cv2.1.2.weight'
# Enabling gradients for parameter 'model.model.23.cv2.1.2.bias'
# Enabling gradients for parameter 'model.model.23.cv2.2.0.conv.weight'
# Enabling gradients for parameter 'model.model.23.cv2.2.0.bn.weight'
# Enabling gradients for parameter 'model.model.23.cv2.2.0.bn.bias'
# Enabling gradients for parameter 'model.model.23.cv2.2.1.conv.weight'
# Enabling gradients for parameter 'model.model.23.cv2.2.1.bn.weight'
# Enabling gradients for parameter 'model.model.23.cv2.2.1.bn.bias'
# Enabling gradients for parameter 'model.model.23.cv2.2.2.weight'
# Enabling gradients for parameter 'model.model.23.cv2.2.2.bias'
# Enabling gradients for parameter 'model.model.23.cv3.0.0.0.conv.weight'
# Enabling gradients for parameter 'model.model.23.cv3.0.0.0.bn.weight'
# Enabling gradients for parameter 'model.model.23.cv3.0.0.0.bn.bias'
# Enabling gradients for parameter 'model.model.23.cv3.0.0.1.conv.weight'
# Enabling gradients for parameter 'model.model.23.cv3.0.0.1.bn.weight'
# Enabling gradients for parameter 'model.model.23.cv3.0.0.1.bn.bias'
# Enabling gradients for parameter 'model.model.23.cv3.0.1.0.conv.weight'
# Enabling gradients for parameter 'model.model.23.cv3.0.1.0.bn.weight'
# Enabling gradients for parameter 'model.model.23.cv3.0.1.0.bn.bias'
# Enabling gradients for parameter 'model.model.23.cv3.0.1.1.conv.weight'
# Enabling gradients for parameter 'model.model.23.cv3.0.1.1.bn.weight'
# Enabling gradients for parameter 'model.model.23.cv3.0.1.1.bn.bias'
# Enabling gradients for parameter 'model.model.23.cv3.0.2.weight'
# Enabling gradients for parameter 'model.model.23.cv3.0.2.bias'
# Enabling gradients for parameter 'model.model.23.cv3.1.0.0.conv.weight'
# Enabling gradients for parameter 'model.model.23.cv3.1.0.0.bn.weight'
# Enabling gradients for parameter 'model.model.23.cv3.1.0.0.bn.bias'
# Enabling gradients for parameter 'model.model.23.cv3.1.0.1.conv.weight'
# Enabling gradients for parameter 'model.model.23.cv3.1.0.1.bn.weight'
# Enabling gradients for parameter 'model.model.23.cv3.1.0.1.bn.bias'
# Enabling gradients for parameter 'model.model.23.cv3.1.1.0.conv.weight'
# Enabling gradients for parameter 'model.model.23.cv3.1.1.0.bn.weight'
# Enabling gradients for parameter 'model.model.23.cv3.1.1.0.bn.bias'
# Enabling gradients for parameter 'model.model.23.cv3.1.1.1.conv.weight'
# Enabling gradients for parameter 'model.model.23.cv3.1.1.1.bn.weight'
# Enabling gradients for parameter 'model.model.23.cv3.1.1.1.bn.bias'
# Enabling gradients for parameter 'model.model.23.cv3.1.2.weight'
# Enabling gradients for parameter 'model.model.23.cv3.1.2.bias'
# Enabling gradients for parameter 'model.model.23.cv3.2.0.0.conv.weight'
# Enabling gradients for parameter 'model.model.23.cv3.2.0.0.bn.weight'
# Enabling gradients for parameter 'model.model.23.cv3.2.0.0.bn.bias'
# Enabling gradients for parameter 'model.model.23.cv3.2.0.1.conv.weight'
# Enabling gradients for parameter 'model.model.23.cv3.2.0.1.bn.weight'
# Enabling gradients for parameter 'model.model.23.cv3.2.0.1.bn.bias'
# Enabling gradients for parameter 'model.model.23.cv3.2.1.0.conv.weight'
# Enabling gradients for parameter 'model.model.23.cv3.2.1.0.bn.weight'
# Enabling gradients for parameter 'model.model.23.cv3.2.1.0.bn.bias'
# Enabling gradients for parameter 'model.model.23.cv3.2.1.1.conv.weight'
# Enabling gradients for parameter 'model.model.23.cv3.2.1.1.bn.weight'
# Enabling gradients for parameter 'model.model.23.cv3.2.1.1.bn.bias'
# Enabling gradients for parameter 'model.model.23.cv3.2.2.weight'
# Enabling gradients for parameter 'model.model.23.cv3.2.2.bias'
# Disabling gradients for parameter 'model.model.23.dfl.conv.weight'
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Using cached teacher weights from: 'C:\Users\jordan\.cache\lightly-train\models\dinov2_vitb14_pretrain.pth'
# Loaded teacher weights from 'C:\Users\jordan\.cache\lightly-train\models\dinov2_vitb14_pretrain.pth'
# Resolved configuration:
# {
#     "accelerator": "CUDAAccelerator",
#     "batch_size": 128,
#     "callbacks": {
#         "device_stats_monitor": null,
#         "early_stopping": {
#             "check_finite": true,
#             "monitor": "train_loss",
#             "patience": 1000000000000
#         },
#         "learning_rate_monitor": {},
#         "model_checkpoint": {
#             "auto_insert_metric_name": true,
#             "dirpath": "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\Experiment_2\\pretrained_from_pretrained_default\\scratch\\checkpoints",
#             "enable_version_counter": false,
#             "every_n_epochs": null,
#             "every_n_train_steps": null,
#             "filename": null,
#             "mode": "min",
#             "monitor": null,
#             "save_last": true,
#             "save_on_train_epoch_end": null,
#             "save_top_k": 1,
#             "save_weights_only": false,
#             "train_time_interval": null,
#             "verbose": false
#         },
#         "model_export": {
#             "every_n_epochs": 1
#         }
#     },
#     "checkpoint": null,
#     "data": [
#         "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\train\\images\\0_db6a96e8.jpg",
#         "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\train\\images\\100519_2125b236.jpg",
#         "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\train\\images\\10249_b8b43c82.jpg",
#         "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\train\\images\\10279_e9d302b4.jpg",
#         "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\train\\images\\102887_6fe6d124.jpg",
#         "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\train\\images\\103816_4a4c2654.jpg",
#         "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\train\\images\\10399_b93a4f38.jpg",
#         "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\train\\images\\104025_5c34ced9.jpg",
#         "... 637 more values",
#         "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\train\\images\\9950_221fe7c3.jpg"
#     ],
#     "devices": 1,
#     "embed_dim": null,
#     "epochs": 200,
#     "float32_matmul_precision": "highest",
#     "loader_args": null,
#     "loggers": {
#         "jsonl": {
#             "flush_logs_every_n_steps": 100
#         },
#         "mlflow": null,
#         "tensorboard": {
#             "default_hp_metric": true,
#             "log_graph": false,
#             "name": "",
#             "prefix": "",
#             "sub_dir": null,
#             "version": ""
#         },
#         "wandb": null
#     },
#     "method": "distillation",
#     "method_args": {
#         "lr_scale_method": "sqrt",
#         "n_projection_layers": 1,
#         "n_teacher_blocks": 2,
#         "projection_hidden_dim": 2048,
#         "reference_batch_size": 1536,
#         "teacher": "dinov2/vitb14-noreg",
#         "teacher_url": null,
#         "teacher_weights": null
#     },
#     "model": "ultralytics/yolo11n.pt",
#     "model_args": null,
#     "num_nodes": 1,
#     "num_workers": 8,
#     "optim": "lars",
#     "optim_args": {
#         "dampening": 0.0,
#         "eps": 1e-08,
#         "lr": 9.0,
#         "momentum": 0.9,
#         "nesterov": false,
#         "trust_coefficient": 0.001,
#         "weight_decay": 1e-06
#     },
#     "out": "C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\Experiment_2\\pretrained_from_pretrained_default/scratch",
#     "overwrite": true,
#     "precision": "bf16-mixed",
#     "resume": null,
#     "resume_interrupted": false,
#     "seed": 0,
#     "strategy": "SingleDeviceStrategy",
#     "trainer_args": null,
#     "transform_args": {
#         "channel_drop": null,
#         "color_jitter": {
#             "brightness": 0.8,
#             "contrast": 0.8,
#             "hue": 0.2,
#             "prob": 0.8,
#             "saturation": 0.4,
#             "strength": 0.5
#         },
#         "gaussian_blur": {
#             "blur_limit": 0,
#             "prob": 1.0,
#             "sigmas": [
#                 0.0,
#                 0.1
#             ]
#         },
#         "image_size": [
#             224,
#             224
#         ],
#         "normalize": {
#             "mean": [
#                 0.485,
#                 0.456,
#                 0.406
#             ],
#             "std": [
#                 0.229,
#                 0.224,
#                 0.225
#             ]
#         },
#         "num_channels": 3,
#         "random_flip": {
#             "horizontal_prob": 0.5,
#             "vertical_prob": 0.0
#         },
#         "random_gray_scale": 0.2,
#         "random_resize": {
#             "max_scale": 1.0,
#             "min_scale": 0.14
#         },
#         "random_rotation": null,
#         "solarize": null
#     }
# }
#
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loading `train_dataloader` to estimate number of stepping batches.
# c:\Users\jordan\miniconda3\envs\coralnet10\lib\site-packages\pytorch_lightning\utilities\_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
#
# c:\Users\jordan\miniconda3\envs\coralnet10\lib\site-packages\pytorch_lightning\utilities\model_summary\model_summary.py:242: Precision bf16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name                    ┃ Type                  ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ teacher_embedding_model │ DinoVisionTransformer │ 86.6 M │ eval  │     0 │
# │ 1 │ student_embedding_model │ EmbeddingModel        │  1.4 M │ train │     0 │
# │ 2 │ student_projection_head │ DistillationV2Head    │  394 K │ train │     0 │
# │ 3 │ criterion               │ DistillationV2Loss    │      0 │ train │     0 │
# └───┴─────────────────────────┴───────────────────────┴────────┴───────┴───────┘
# Trainable params: 1.8 M
# Non-trainable params: 86.6 M
# Total params: 88.3 M
# Total estimated model params size (MB): 353
# Modules in train mode: 159
# Modules in eval mode: 211
# Total FLOPs: 0
# Training: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=200` reached.
# Training completed.
# Example: How to use the exported model
# ----------------------------------------------------------------------------------------
# from ultralytics import YOLO
#
# # Load the pretrained model
# model = YOLO('C:\Users\jordan\Documents\GitHub\CoralNet-Toolbox\data\cac\PUS\Experiment_2\pretrained_from_pretrained_default\scratch\exported_models\exported_last.pt')
#
# # Finetune or evaluate the model
# ...
# ----------------------------------------------------------------------------------------
#
# Model exported.

# %% [markdown]
# And just like that you pretrained a YOLO11s backbone! 🥳 This backbone can't solve any task yet, so in the next step we will finetune it for object detection on the PASCAL VOC dataset.
#
# ## Finetuning on PASCAL VOC
# Now that the pretrained model has been exported, we will further fine-tune the model on the task of object detection. The exported model already has exactly the format that Ultralytics' YOLO expects, so after getting the dataset ready, we can get started with only a few lines! ⚡️
#
# In addition to fine-tuning the pretrained model we will also train a model that we initialize with random weights. This will let us compare the performance between the two, and show the great benefits of pretraining.
#
# Expect again a run-time of around 1h each, for fine-tuning from the pretrained model, as well as fine-tuning from randomly initialized weights.
#
# ### Download the PASCAL VOC Dataset
# We can download the dataset directly using Ultralytics' API with the `check_det_dataset` function:

# %%
from ultralytics.data.utils import check_det_dataset

dataset = check_det_dataset("C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\data.yaml")

# %% [markdown]
# Ultralytics always downloads your datasets to a fixed location, which you can fetch via their `settings` module:

# %%
from ultralytics import settings

print(settings["datasets_dir"])

# %% [markdown]
# Inside that directory (<DATASET-DIR>), you will now have the following structure of images and labels:
#
# ```bash
# tree -d <DATASET-DIR>/VOC -I VOCdevkit
#
# >    datasets/VOC
# >    ├── images
# >    │   ├── test2007
# >    │   ├── train2007
# >    │   ├── train2012
# >    │   ├── val2007
# >    │   └── val2012
# >    └── labels
# >        ├── test2007
# >        ├── train2007
# >        ├── train2012
# >        ├── val2007
# >        └── val2012
# ```
#
# ### Inspect a few Images
#
# Let's use `supervision` and look at a few of the annotated samples to get a feeling of what the data looks like:

# %%
import random

import matplotlib.pyplot as plt
import supervision as sv
import yaml
from ultralytics import settings
from ultralytics.data.utils import check_det_dataset

dataset = check_det_dataset("VOC.yaml")

detections = sv.DetectionDataset.from_yolo(
    data_yaml_path=dataset["yaml_file"],
    images_directory_path=f"{settings['datasets_dir']}/VOC/images/train2012",
    annotations_directory_path=f"{settings['datasets_dir']}/VOC/labels/train2012",
)

with open(dataset["yaml_file"], "r") as f:
    data = yaml.safe_load(f)

names = data["names"]

box_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator()

fig, ax = plt.subplots(2, 2, figsize=(10, 10))
ax = ax.flatten()

detections = [detections[random.randint(0, len(detections))] for _ in range(4)]

for i, (path, image, annotation) in enumerate(detections):
    annotated_image = box_annotator.annotate(scene=image, detections=annotation)
    annotated_image = label_annotator.annotate(
        scene=annotated_image,
        detections=annotation,
        labels=[names[elem] for elem in annotation.class_id],
    )
    ax[i].imshow(annotated_image[..., ::-1])
    ax[i].axis("off")

fig.tight_layout()
fig.show()

# %% [markdown]
# ### Finetuning the Pretrained Model
# All we have to do is to pass the path to the pretrained model to the `YOLO` class and the rest is the same as always with Ultralytics.

# %%
from ultralytics import YOLO

# Load the exported model.
model = YOLO("C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\notebooks\\output\\scratch\\exported_models\\exported_last.pt")

# Fine-tune with ultralytics.
model.train(
    data="C:\\Users\\jordan\\Documents\\GitHub\\CoralNet-Toolbox\\data\\cac\\PUS\\fully_annotated\\data.yaml", epochs=10, project="logs/voc_yolo11s", name="from_pretrained"
)

# %% [markdown]
# ### Finetuning from Random Weights
# In order to quantify the influence of our pretraining, we also train a model from random weights, in Ultralytics this follows the `.yaml` name convention.

# %%
from ultralytics import YOLO

# Load the exported model.
model = YOLO("yolo11s.yaml")

# Fine-tune with ultralytics.
model.train(data="VOC.yaml", epochs=10, project="logs/voc_yolo11s", name="from_scratch")

# %% [markdown]
# ## Evaluating the Model Performance
# Congratulations, you made it almost to the end! 🎉 The last thing we'll do is to analyze the performance between the two. A very common metric to measure the performance of object detectors is the `mAP50-95` which we plot in the next cell, for both the pretrained model and the model that we trained from scratch.

# %%
import matplotlib.pyplot as plt
import pandas as pd

res_scratch = pd.read_csv("logs/voc_yolo11s/from_scratch/results.csv")
res_finetune = pd.read_csv("logs/voc_yolo11s/from_pretrained/results.csv")

fig, ax = plt.subplots()
ax.plot(res_scratch["epoch"], res_scratch["metrics/mAP50-95(B)"], label="scratch")
ax.plot(res_finetune["epoch"], res_finetune["metrics/mAP50-95(B)"], label="finetune")
ax.set_xlabel("Epoch")
ax.set_ylabel("mAP50-95")
max_pretrained = res_finetune["metrics/mAP50-95(B)"].max()
max_scratch = res_scratch["metrics/mAP50-95(B)"].max()
ax.set_title(
    f"Pretraining is {(max_pretrained - max_scratch) / max_scratch * 100:.2f}% better than scratch"
)
ax.legend()

# %% [markdown]
# ## Next Steps
#  - Go beyond the default distillation pretraining and experiment other pretraining learning methods in LightlyTrain. Check [Methods](https://docs.lightly.ai/train/stable/pretrain_distill/methods/index.html#methods) for more information.
#  - Try various YOLO models (`YOLOv5`, `YOLOv6`, `YOLOv8`).
#  - Use the pretrained model for other tasks, like [image embeddings](https://docs.lightly.ai/train/stable/embed.html#embed).
