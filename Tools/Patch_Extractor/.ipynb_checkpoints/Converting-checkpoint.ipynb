# %%
from patch_extractor_utils import *

import glob
import random
import matplotlib.pyplot as plt

# %%
# Folder containing all the txt files output by Patch Extractor tool
folder = "TXT_Files"

# Patch Extractor tool provides the xy location of top-left corner
# To make the points centered in the patch, patch size needs to be known.
patch_size = 224

# %%
files = glob.glob(folder + "/*.txt")
df = pd.concat([txt_to_csv(file, patch_size=224) for file in files])

# %%
df.sample(10)
# Out:
#                                             File_Path  Column   Row Label  \
# 61  C:\Users\jordan.pierce\Pictures\Nancy_Foster_2...    2886  1862  Fish
# 13  C:\Users\jordan.pierce\Pictures\Nancy_Foster_2...    2233  1514  Fish
# 26  C:\Users\jordan.pierce\Pictures\Nancy_Foster_2...    2635  2592  Fish
# 11  C:\Users\jordan.pierce\Pictures\Nancy_Foster_2...    2353  1510  Fish
# 53  C:\Users\jordan.pierce\Pictures\Nancy_Foster_2...    1514  1510  Fish
# 6   C:\Users\jordan.pierce\Pictures\Nancy_Foster_2...    2334  1661  Base
# 20  C:\Users\jordan.pierce\Pictures\Nancy_Foster_2...    1615   869  Fish
# 36  C:\Users\jordan.pierce\Pictures\Nancy_Foster_2...    1279  1878  Fish
# 5   C:\Users\jordan.pierce\Pictures\Nancy_Foster_2...    2403  1595  Base
# 27  C:\Users\jordan.pierce\Pictures\Nancy_Foster_2...     966  1731  Fish
#
#                         Name
# 61  Dive 957_0007_152903.JPG
# 13  Dive 957_0002_152450.JPG
# 26  Dive 957_0005_152847.JPG
# 11  Dive 957_0002_152450.JPG
# 53  Dive 018_0015_083857.JPG
# 6   Dive 957_0011_153015.JPG
# 20  Dive 018_0003_083132.JPG
# 36  Dive 957_0006_152852.JPG
# 5   Dive 957_0011_153015.JPG
# 27  Dive 018_0003_083132.JPG

# %%
sample = df[df['Name'] == df.iloc[random.randint(0, len(df))]['Name']]

image_path = sample.iloc[0]['File_Path']
y = sample['Row'].values
x = sample['Column'].values

plt.figure(figsize=(10, 10))
plt.scatter(x, y, c='red')
plt.imshow(plt.imread(image_path))
plt.show()

# %%
df.to_csv("Combined_Annotations.csv")
