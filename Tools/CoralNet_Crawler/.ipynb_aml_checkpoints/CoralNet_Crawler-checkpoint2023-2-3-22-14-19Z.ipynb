# %%
import os
import io

import requests
import pandas as pd
import multiprocessing
from bs4 import BeautifulSoup

# -----------------------------------------------------------------------------
# Configurations
# -----------------------------------------------------------------------------

# Constant for the CoralNet url
CORALNET_URL = "https://coralnet.ucsd.edu"

# URL of the login page
LOGIN_URL = "https://coralnet.ucsd.edu/accounts/login/"

# The source id of the source you want to download all the images from
SOURCE_ID = 3361

# Constant URLs for getting images, labelset, and annotations
SOURCE_URL = CORALNET_URL + "/source/" + str(SOURCE_ID)
IMAGE_URL = SOURCE_URL + "/browse/images/"
LABELSET_URL = SOURCE_URL + "/export/labelset/"

# The directory to store the output
SOURCE_DIR = "./" + str(SOURCE_ID) + "/"
IMAGE_DIR = SOURCE_DIR + "images/"

# Creating the directories
os.makedirs(SOURCE_DIR, exist_ok=True)
os.makedirs(IMAGE_DIR, exist_ok=True)

# Set the username and password for your CoralNet account locally, that way
# credentials never need to be entered in the script (wherever it is).

# Be sure to restart the terminal when first setting environmental variables
# for them to be saved!
USERNAME = os.getenv('CORALNET_USERNAME')
PASSWORD = os.getenv('CORALNET_PASSWORD')

USERNAME = "jordan.pierce@noaa.gov"
PASSWORD = "~Howdyaggies777"


# -----------------------------------------------------------------------------
# Functions
# -----------------------------------------------------------------------------


def url_to_soup(url):
    """
    Takes a URL and returns a BeautifulSoup object for the HTML at the URL.

    Args: url (str): The URL of the webpage to be converted to a
    BeautifulSoup object.

    Returns:
        soup (BeautifulSoup): The BeautifulSoup object for the HTML at the URL.
    """

    # Send an HTTP GET request to the URL and store the response
    response = requests.get(url)

    # Parse the HTML, store in soup
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')

    return soup


def crawl(page_url):
    """
    Crawl a coralnet image page and get the associated image path url and
    the url of the next image page.

    Args:
        page_url (str): The URL of the coralnet image page to crawl.

    Returns: tuple: A tuple containing the image page URL, image path URL,
    and the URL of the next image page.
    """

    image_name = None
    image_page_url = page_url
    image_path_url = None
    next_image_page_url = None

    # From the provided image page url, get the associated image path url
    soup = url_to_soup(page_url)

    # Find the div element with id="original_image_container" and
    # style="display:none;"
    orginal_image_container = soup.find('div',
                                        id='original_image_container',
                                        style='display:none;')

    # Find the img element within the div and get the value of the src
    # attribute
    image_path_url = orginal_image_container.find('img').get('src')

    # Now, get the next page's url
    for a_tag in soup.find_all('a'):
        # check if the text of the <a> tag contains "Next"
        if "Next" in a_tag.text:
            # Get the value of the href attribute and prepend the CORALNET_URL
            next_image_page_url = CORALNET_URL + a_tag.get('href')

        # Else, it returns None, and we know we're at the end of the images

    # Finally, get the name of the image, because when downloaded it might
    # not match
    image_name = soup.find('title').text.split(" |")[0]

    return image_name, image_page_url, image_path_url, next_image_page_url


def download_labelset(labelset_url):
    """
    Downloads a .csv file holding the label set from the given URL.
    Args:
        labelset_url (str): The URL of the website with the download button.
    Returns:
        None
    """

    print("Downloading labelset...")

    # Make an HTTP GET request to download the .csv file
    response = requests.get(labelset_url,
                            params={"submit": "Export label entries to CSV"})

    # Check the response status code
    if response.status_code == 200:
        # Save the .csv file to a local directory
        with open(SOURCE_DIR + "label_set.csv", "wb") as f:
            f.write(response.content)

    if os.path.exists(SOURCE_DIR + "label_set.csv"):
        print("Label set saved to: ", SOURCE_DIR + "label_set.csv")
    else:
        print("Could not download label set.")


def download_annotations(image_url):
    """
    This function downloads the annotations from a CoralNet source using the
    provided image URL. It logs into CoralNet using the provided username
    and password, and exports the annotations for the images in the source
    as a CSV file, which is saved in the local source directory.

    :param image_url: A string containing the URL of an image in the source
    """

    print("Downloading annotations...")

    # Send a GET request to the login page to retrieve the login form
    response = requests.get(LOGIN_URL)

    # Pass along the cookies
    cookies = response.cookies

    # Parse the HTML of the response using BeautifulSoup
    soup = BeautifulSoup(response.text, "html.parser")

    # Extract the CSRF token from the HTML of the login page
    csrf_token = soup.find("input", attrs={"name": "csrfmiddlewaretoken"})

    # Create a dictionary with the login form fields and their values
    # (replace "username" and "password" with your actual username and
    # password)
    data = {
        "username": USERNAME,
        "password": PASSWORD,
        "csrfmiddlewaretoken": csrf_token["value"],
    }

    # Include the "Referer" header in the request
    headers = {
        "Referer": LOGIN_URL,
    }

    # Use requests.Session to create a session that will maintain your login
    # state
    with requests.Session() as session:

        # Use session.post() to submit the login form, including the
        # "Referer" header
        response = session.post(LOGIN_URL,
                                data=data,
                                headers=headers,
                                cookies=cookies)

        # Use session.get() to make a GET request to the source URL
        response = session.get(image_url)

        # Pass along the cookies
        cookies = response.cookies

        # Parse the HTML response using BeautifulSoup
        soup = BeautifulSoup(response.text, "html.parser")

        # Find the form in the HTML
        form = soup.find("form", {"id": "export-annotations-form"})

        # Extract the form fields (input elements)
        inputs = form.find_all("input")

        # Create a dictionary with the form fields and their values
        data = {'optional_columns': []}
        for i, input in enumerate(inputs):
            if i == 0:
                data[input["name"]] = input["value"]
            else:
                data['optional_columns'].append(input['value'])

        # Use session.post() to submit the form
        response = session.post(CORALNET_URL + form["action"],
                                data=data,
                                headers=headers,
                                cookies=cookies)

        # Check the response status code
        if response.status_code == 200:
            # Convert the text in response to a dataframe
            df = pd.read_csv(io.StringIO(response.text), sep=",")
            # Save the dataframe locally
            df.to_csv(SOURCE_DIR + "annotations.csv")

        else:
            print("Could not connect with CoralNet; please ensure that you "
                  "entered your username, password, and source ID correctly.")

    if os.path.exists(SOURCE_DIR + "label_set.csv"):
        print("Annotations saved to: ", SOURCE_DIR + "annotations.csv")
    else:
        print("Could not download annotations.")


def download_image(row):
    """
    Downloads a single image from the given URL, using the provided file name
    to save the image to a local directory.

    Args:
        row (list): A list containing the file name and URL of the image to
            download. The list should have at least two elements: the file
            name and the URL.

    Returns:
        None
    """

    # the output path of the image being downloaded
    image_path = IMAGE_DIR + row[0]

    # Make an HTTP GET request to download the image
    response = requests.get(row[2])

    # Check the response status code
    if response.status_code == 200:
        # Save the image to a file in the output directory
        with open(image_path, 'wb') as f:
            f.write(response.content)

        if os.path.exists(image_path):
            print("File downloaded: ", image_path)
        else:
            print("File could not be downloaded: ", image_path)


def download_images(image_url):
    """
    Downloads images from a list of URLs, using file names from a pandas
    dataframe to save the images to a local directory.

    Args: df (pandas.DataFrame): A dataframe containing the file names and
    URLs of the images to download. The dataframe should have at least two
    columns: 'file_name' and 'image_url'.

    Returns:
        None
    """

    print("Downloading images...")

    # A list containing the urls to all the image pages and a list containing
    # the urls to all the images hosted on amazon
    image_names = []
    image_page_urls = []
    image_path_urls = []

    # Convert the webpage to soup
    soup = url_to_soup(image_url)

    # Grab the first image page url
    images_divs = soup.find('span', class_='thumb_wrapper')
    image_href = images_divs.find_all('a')[0].get("href")
    next_page_url = CORALNET_URL + image_href

    # Crawl across all image page urls, grabbing the image path url as well
    # as the next page url continue doing this until the end of the source
    # project image pages, where there is no next.
    while next_page_url is not None:

        name, page_url, path_url, next_page_url = crawl(next_page_url)
        
        image_names.append(name)
        image_page_urls.append(page_url)
        image_path_urls.append(path_url)

        print(name, page_url, path_url)

    # Storing the results in dataframe
    df = pd.DataFrame(list(zip(image_names, image_page_urls, image_path_urls)),
                      columns=['image_name', 'image_page', 'image_url'])
    # Saving locally
    df.to_csv(SOURCE_DIR + str(SOURCE_ID) + "_images.csv")

    # Use the multiprocessing library's Pool.map() method to download images
    # in parallel
    with multiprocessing.Pool() as pool:
        # Apply the download_image function to each row in the dataframe
        pool.map(download_image, df.values.tolist())


if __name__ == "__main__":

    """This is the main function of the script. It calls the functions
    download_labelset, download_annotations, and download_images to download
    the label set, annotations, and images, respectively. """

    # Download the label set as a csv
    download_labelset(LABELSET_URL)

    # Check to see if user credentials have been set,
    # if not, annotations cannot be downloaded; skip.
    if not None in [USERNAME, PASSWORD, None]:
        # Download the annotations as a csv
        download_annotations(IMAGE_URL)

    # Download all the images
    download_images(IMAGE_URL)

    print("Done.")
# Out:
# Downloading labelset...
# Label set saved to:  ./3361/label_set.csv
# Downloading images...
# 2022-04-21-AGAT-T06-01.0(P4210240).JPG https://coralnet.ucsd.edu/image/2597151/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/poisy1u1bn.JPG?Signature=VqfpteJYbCPGs0NLGC4uHCL0sJw%3D&Expires=1677876429&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-02.0(P4210242).JPG https://coralnet.ucsd.edu/image/2597152/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/hc97ojn1ez.JPG?Signature=ew%2BzuHAZLJo2iMuzy1agblildKY%3D&Expires=1677876430&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-03.0(P4210243).JPG https://coralnet.ucsd.edu/image/2597153/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/uq2wgq3xsj.JPG?Signature=kUj33KlOLlPVYwLtELGsUCOd6z4%3D&Expires=1677876431&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-04.0(P4210244).JPG https://coralnet.ucsd.edu/image/2597154/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/ek5ab8t9ni.JPG?Signature=9T7DfnDHG03LoKs387hZ8myF4yo%3D&Expires=1677876431&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-05.0(P4210246).JPG https://coralnet.ucsd.edu/image/2597155/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/xd3k93dz95.JPG?Signature=2cqdUdgGt0LQ%2FwWEBiMcb0Lbewo%3D&Expires=1677876432&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-06.0(P4210247).JPG https://coralnet.ucsd.edu/image/2597156/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/3vytqcme6g.JPG?Signature=0x5cW5eyTk9HDcWsvVsCgAA9bTo%3D&Expires=1677876432&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-07.0(P4210248).JPG https://coralnet.ucsd.edu/image/2597157/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/emk4f5h5mj.JPG?Signature=VUTpg16O%2FPo86NK8wM%2BzdNaH%2BtA%3D&Expires=1677876433&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-08.0(P4210249).JPG https://coralnet.ucsd.edu/image/2597158/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/o0vfynx5qc.JPG?Signature=6FuYoIqT0kO%2Bi5cHnm%2FVQpPLRYw%3D&Expires=1677876434&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-09.0(P4210250).JPG https://coralnet.ucsd.edu/image/2597159/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/jo8mf4l3sk.JPG?Signature=bmqsunBRObj9ElAvOHJWV1ArUqI%3D&Expires=1677876434&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-10.0(P4210252).JPG https://coralnet.ucsd.edu/image/2597160/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/ed06ex4pvc.JPG?Signature=KlZUDysuDtCHQG1B3xeltzywIi4%3D&Expires=1677876435&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-11.0(P4210253).JPG https://coralnet.ucsd.edu/image/2597161/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/lazyxevl3k.JPG?Signature=a0eRbMSMm%2Bs2UxGr7vfm%2FGNZ9OI%3D&Expires=1677876435&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-12.0(P4210254).JPG https://coralnet.ucsd.edu/image/2597162/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/sr11af8pgp.JPG?Signature=sFtsz1Gnc0TBUpFYVUagbS60sy8%3D&Expires=1677876436&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-13.0(P4210257).JPG https://coralnet.ucsd.edu/image/2597163/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/izh0llswz0.JPG?Signature=%2Bn5YGWnPKvzs9oafYEjNlFcdp4c%3D&Expires=1677876437&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-14.0(P4210258).JPG https://coralnet.ucsd.edu/image/2597164/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/6o1iumb6cf.JPG?Signature=mg%2F4SO54e1DU7AD05rBumxknUus%3D&Expires=1677876437&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-15.0(P4210259).JPG https://coralnet.ucsd.edu/image/2597165/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/du3k9dclvs.JPG?Signature=DxPldvVEIc7IeoluETmnFzcuVB4%3D&Expires=1677876438&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-16.0(P4210261).JPG https://coralnet.ucsd.edu/image/2597166/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/lcusjk69st.JPG?Signature=QzqGm8HOspub8wH9aYwIJNS2quQ%3D&Expires=1677876438&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-17.0(P4210262).JPG https://coralnet.ucsd.edu/image/2597167/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/u96b7lwf5y.JPG?Signature=g%2BKJqic2oj%2BI5AJD4B9qvtGw6Rk%3D&Expires=1677876439&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-18.0(P4210263).JPG https://coralnet.ucsd.edu/image/2597168/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/9d0hgclcik.JPG?Signature=H1QxlOottDCXQYXT4sez3vx%2B3Z0%3D&Expires=1677876439&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-19.0(P4210264).JPG https://coralnet.ucsd.edu/image/2597169/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/gogs1xhbox.JPG?Signature=X5n1B6UcHceBCRDl%2FdGrIWx226o%3D&Expires=1677876440&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-20.0(P4210265).JPG https://coralnet.ucsd.edu/image/2597170/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/u676rakwdu.JPG?Signature=9igulGEGIi%2BbfhiVfsC9PDAr2Y4%3D&Expires=1677876440&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-21.0(P4210266).JPG https://coralnet.ucsd.edu/image/2597171/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/5jmg5u5ihy.JPG?Signature=8O11L4B4IKXw5nLDfZ4p%2FfBFDeg%3D&Expires=1677876441&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-22.0(P4210269).JPG https://coralnet.ucsd.edu/image/2597172/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/mj2bmvf22i.JPG?Signature=nCPMZSUuHE0%2FVUwHCmt%2BV5hkjkg%3D&Expires=1677876441&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-23.0(P4210270).JPG https://coralnet.ucsd.edu/image/2597173/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/o555upmy1c.JPG?Signature=PG42x2t1kJ8aj%2BEj1n7CNFJtHDs%3D&Expires=1677876442&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-24.0(P4210271).JPG https://coralnet.ucsd.edu/image/2597174/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/95eq9myo86.JPG?Signature=kRrNLf7ciFMXFaZ9CVIhhpihyGY%3D&Expires=1677876442&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-25.0(P4210272).JPG https://coralnet.ucsd.edu/image/2597175/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/ja226m98ca.JPG?Signature=PSaK4MvKYAkgJoiN%2BdlqT%2F6rm2M%3D&Expires=1677876443&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-26.0(P4210273).JPG https://coralnet.ucsd.edu/image/2597176/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/lq1fycvqid.JPG?Signature=nksO3IoB8aJYPaPRXf3HxhJ1e8g%3D&Expires=1677876443&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-27.0(P4210274).JPG https://coralnet.ucsd.edu/image/2597177/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/9nqlxs8ccx.JPG?Signature=zL3k4NCc5lU6jNNfJuF2qF4lkrk%3D&Expires=1677876444&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-28.0(P4210275).JPG https://coralnet.ucsd.edu/image/2597178/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/ohlqzk30hr.JPG?Signature=1eAG0%2F3L4h98ZO2MlJtlPRG%2F4xE%3D&Expires=1677876444&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-29.0(P4210276).JPG https://coralnet.ucsd.edu/image/2597179/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/g15yzh1zbw.JPG?Signature=Br3q0OiFi8k46GH4kGwuzqNcSP4%3D&Expires=1677876445&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-30.0(P4210277).JPG https://coralnet.ucsd.edu/image/2597180/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/5zfzd0qqa6.JPG?Signature=lwxVBh75fD9rZZSmIIfIhtS4WOY%3D&Expires=1677876445&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-31.0(P4210278).JPG https://coralnet.ucsd.edu/image/2597181/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/bxpgp45riq.JPG?Signature=CuW%2BLrJbbH%2F%2BdcWPotGanB%2FCGmc%3D&Expires=1677876446&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-32.0(P4210279).JPG https://coralnet.ucsd.edu/image/2597182/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/qh16ga34wq.JPG?Signature=iRF7cxhxwTZPWEe14qMJXyp%2BR%2BU%3D&Expires=1677876447&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-33.0(P4210280).JPG https://coralnet.ucsd.edu/image/2597183/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/lueam6ri0x.JPG?Signature=Im789Cmv7qTXWcLEoNTGFJwA7Eg%3D&Expires=1677876447&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-34.0(P4210281).JPG https://coralnet.ucsd.edu/image/2597184/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/put1ypaux2.JPG?Signature=k8ywyE0jr8BiuOVIzZ0yv8h4n54%3D&Expires=1677876448&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-35.0(P4210282).JPG https://coralnet.ucsd.edu/image/2597185/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/ynfydx04be.JPG?Signature=VRjuLR%2BfW4uZpl26l6SUWEGbqcY%3D&Expires=1677876448&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-36.0(P4210284).JPG https://coralnet.ucsd.edu/image/2597186/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/aijb3z5lf0.JPG?Signature=4G%2Fsjw5xOcWX1fmWrPa6JzWxbVA%3D&Expires=1677876448&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-37.0(P4210285).JPG https://coralnet.ucsd.edu/image/2597187/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/uv595hnbwz.JPG?Signature=cFgcsv4FDNRSVGQXPKA%2FBNxdLkE%3D&Expires=1677876449&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-38.0(P4210286).JPG https://coralnet.ucsd.edu/image/2597188/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/tof0c2mlbg.JPG?Signature=j3qZhydzqVzBkT8b067Y5PUhSTc%3D&Expires=1677876449&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-39.0(P4210287).JPG https://coralnet.ucsd.edu/image/2597189/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/e1z3a8wuv9.JPG?Signature=nUGlik7oJt63Gb9BFDbfg9klyCk%3D&Expires=1677876450&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-40.0(P4210288).JPG https://coralnet.ucsd.edu/image/2597190/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/z54yzedn5w.JPG?Signature=rb7ezP%2Bb75uhKOJYrRzsWwvFSqY%3D&Expires=1677876451&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-41.0(P4210289).JPG https://coralnet.ucsd.edu/image/2597191/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/5tg884tn8e.JPG?Signature=5FSe0qy%2BLW7cu60NktKMLC1Mww8%3D&Expires=1677876451&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-42.0(P4210290).JPG https://coralnet.ucsd.edu/image/2597192/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/ie1jc71ls2.JPG?Signature=8VpqqXHNe7J%2BHuX1aVy8d54bE24%3D&Expires=1677876452&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-43.0(P4210291).JPG https://coralnet.ucsd.edu/image/2597193/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/29govhakr2.JPG?Signature=UqEElFY3ATlHecLrKC%2F7vlqou8I%3D&Expires=1677876452&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-44.0(P4210292).JPG https://coralnet.ucsd.edu/image/2597194/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/hvnulbj98g.JPG?Signature=AFwyAbe%2BhisCb1D1SgdO5z7tv6Y%3D&Expires=1677876453&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-45.0(P4210294).JPG https://coralnet.ucsd.edu/image/2597195/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/kggk9g72li.JPG?Signature=dIovpcCjoqw7%2BeWI32jPzBUJsTk%3D&Expires=1677876453&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-46.0(P4210295).JPG https://coralnet.ucsd.edu/image/2597196/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/bqifwr34gt.JPG?Signature=okfzdUqGCr1PYup8PSrukVXzXrQ%3D&Expires=1677876454&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-47.0(P4210296).JPG https://coralnet.ucsd.edu/image/2597197/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/ccdxjip8e5.JPG?Signature=CsZwJa3076DSMb0CZca7TdTXHS8%3D&Expires=1677876454&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-48.0(P4210297).JPG https://coralnet.ucsd.edu/image/2597198/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/pubo3ndz1i.JPG?Signature=qtVeijHIfPlEo%2B6VAgeOeGvHjxc%3D&Expires=1677876455&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-49.0(P4210298).JPG https://coralnet.ucsd.edu/image/2597199/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/ln5vl63yz6.JPG?Signature=PVZx4EblQNtnbl83YSq7Zjf1qNY%3D&Expires=1677876455&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T06-50.0(P4210299).JPG https://coralnet.ucsd.edu/image/2597200/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/qgqyvjrf10.JPG?Signature=IJ28Rd%2FXZB2xTKYkniDu4zLtljg%3D&Expires=1677876456&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-01.0(P4210021).jpg https://coralnet.ucsd.edu/image/2607068/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/mcpsmweg04.jpg?Signature=Rl1mqIZ3yZG2tjl5n2ku%2BezmWUk%3D&Expires=1677876456&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-02.0(P4210022).jpg https://coralnet.ucsd.edu/image/2607069/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/qi4e3qqjr4.jpg?Signature=Ylq1cUVFVbOckfIzBsLOUSe150s%3D&Expires=1677876457&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-03.0(P4210023).jpg https://coralnet.ucsd.edu/image/2607070/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/3yvl3asn6q.jpg?Signature=oZTsXcfj9apOa1k2V7EbIFQN1h0%3D&Expires=1677876457&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-04.0(P4210024).jpg https://coralnet.ucsd.edu/image/2607077/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/sbx8l262k9.jpg?Signature=o2H5VFejRqx2tvMvSFyPjBjf0aY%3D&Expires=1677876458&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-05.0(P4210025).jpg https://coralnet.ucsd.edu/image/2607084/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/wh9qazw986.jpg?Signature=Y18WiXxSpi0il6qqB0qrJR%2FyWuQ%3D&Expires=1677876458&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-06.0(P4210026).jpg https://coralnet.ucsd.edu/image/2607090/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/nxxm5zsy0t.jpg?Signature=smfYV%2B%2FcT8kp8noJrpeCX2gAYe0%3D&Expires=1677876458&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-07.0(P4210027).jpg https://coralnet.ucsd.edu/image/2607094/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/pm50h8i79q.jpg?Signature=6Zyzt6VS6lO8OXH1Ip0SPKWfA6U%3D&Expires=1677876459&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-08.0(P4210029).jpg https://coralnet.ucsd.edu/image/2607095/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/5b2vedtnxk.jpg?Signature=9FbqfIYCUoa73dfqQGzAb8i%2FkTQ%3D&Expires=1677876459&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-09.0(P4210030).jpg https://coralnet.ucsd.edu/image/2607096/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/wt6s41a848.jpg?Signature=MFUxMsqiTRK1VOxhZ8mR2HUooqc%3D&Expires=1677876460&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-10.0(P4210031).jpg https://coralnet.ucsd.edu/image/2607101/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/ctel1xctdk.jpg?Signature=AfnY2rMp612%2Bv08t8lqp9aHm5cA%3D&Expires=1677876461&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-11.0(P4210032).jpg https://coralnet.ucsd.edu/image/2607108/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/4yx07fgecl.jpg?Signature=6vN33wC4Ylei44l86nvh8GN%2Bu%2Bg%3D&Expires=1677876461&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-12.0(P4210033).jpg https://coralnet.ucsd.edu/image/2607117/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/k0i7bwbs4p.jpg?Signature=Yc3P17F%2F%2FtcOuc3O6ZBKpIaTxGg%3D&Expires=1677876462&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-13.0(P4210034).jpg https://coralnet.ucsd.edu/image/2607120/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/92cno6ahrk.jpg?Signature=d1Wk%2B8iyRnAKxBNIG6VWBYN3U%2BQ%3D&Expires=1677876462&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-14.0(P4210035).jpg https://coralnet.ucsd.edu/image/2607122/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/11nqw5dnby.jpg?Signature=4%2BOS2SP9RulquCy0RadBBPpmGxw%3D&Expires=1677876463&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-15.0(P4210036).jpg https://coralnet.ucsd.edu/image/2607123/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/33kvl7bjkw.jpg?Signature=D9WVOZT5vXPKQTiWNhGkA5ZeJA8%3D&Expires=1677876463&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-16.0(P4210038).jpg https://coralnet.ucsd.edu/image/2607126/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/hzm2ik11y2.jpg?Signature=fW1WhuLD28Og6%2FB5Dnc3JOn43JY%3D&Expires=1677876463&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-17.0(P4210039).jpg https://coralnet.ucsd.edu/image/2607134/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/6h977b4w11.jpg?Signature=NCKtGT4CU7ZslvjRDUlhQ4%2FvIHg%3D&Expires=1677876464&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-18.0(P4210040).jpg https://coralnet.ucsd.edu/image/2607142/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/9gf0i07clm.jpg?Signature=%2B%2B5E5JeUxeRPzJQ4bLkDk7Gy6yI%3D&Expires=1677876464&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-19.0(P4210041).jpg https://coralnet.ucsd.edu/image/2607146/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/7v9xtus4w4.jpg?Signature=Ed52FL1%2BwE%2Bx5vLPCoiOwaaYpaE%3D&Expires=1677876465&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-20.0(P4210042).jpg https://coralnet.ucsd.edu/image/2607150/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/otl2zreohd.jpg?Signature=%2BRhUFxga1FXRIxWh53lZlOf4Bys%3D&Expires=1677876465&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-21.0(P4210043).jpg https://coralnet.ucsd.edu/image/2607152/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/36uhkg5t63.jpg?Signature=f%2BEk3pKbYdV1lx8nY4l3xDsUaJY%3D&Expires=1677876466&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-22.0(P4210044).jpg https://coralnet.ucsd.edu/image/2607153/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/jnwbz39vrh.jpg?Signature=lEzJKnuQzWBx%2BYUbHbtdI1f9MgI%3D&Expires=1677876466&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-23.0(P4210045).jpg https://coralnet.ucsd.edu/image/2607154/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/uhnyw5i9tx.jpg?Signature=W9yywHy9WhDcm8%2BB%2F%2FhOroekX8Y%3D&Expires=1677876467&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-24.0(P4210046).jpg https://coralnet.ucsd.edu/image/2607156/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/rdf7lehdf9.jpg?Signature=8CYszmhNVJu8ByxS2GZrT4ty%2BSc%3D&Expires=1677876467&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-25.0(P4210047).jpg https://coralnet.ucsd.edu/image/2607157/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/lxbpt70pbg.jpg?Signature=ie2MGVi%2B5%2Fwq%2BBKBzz1G%2FkG46nk%3D&Expires=1677876468&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-26.0(P4210048).jpg https://coralnet.ucsd.edu/image/2607159/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/8be4j7e5b4.jpg?Signature=fMEvdQXKc4VqsuQYbBBOTanCm7s%3D&Expires=1677876468&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-27.0(P4210049).jpg https://coralnet.ucsd.edu/image/2607160/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/n8a8xm6l1a.jpg?Signature=YNaaFoKr%2ByrkwokpXGc2%2Baqe%2F%2FQ%3D&Expires=1677876469&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-28.0(P4210050).jpg https://coralnet.ucsd.edu/image/2607161/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/2t8jnrfx2y.jpg?Signature=NmLjDiayRhYvooMDhxadWCEF2N4%3D&Expires=1677876469&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-29.0(P4210051).jpg https://coralnet.ucsd.edu/image/2607163/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/a8jsoewe3u.jpg?Signature=qt1M8gt%2F93E5F74oR4tZ1svgZnc%3D&Expires=1677876470&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-30.0(P4210052).jpg https://coralnet.ucsd.edu/image/2607164/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/w40lyd0atf.jpg?Signature=JEOac5L0mo5LQrc0M4ltoH0bd28%3D&Expires=1677876470&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-31.0(P4210054).jpg https://coralnet.ucsd.edu/image/2607165/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/9rl960qbhp.jpg?Signature=wkJW%2FmxAzm6ZT7zigCs0V5%2BM8Dk%3D&Expires=1677876471&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-32.0(P4210055).jpg https://coralnet.ucsd.edu/image/2607167/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/dge1djhco3.jpg?Signature=OKAXTB2hZa8Bs2NvY0ZcYbN1Ixk%3D&Expires=1677876471&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-33.0(P4210056).jpg https://coralnet.ucsd.edu/image/2607168/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/8ei60f8mxr.jpg?Signature=pYHBQvNoH2JRtt0khi8l7H4f2AY%3D&Expires=1677876472&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-34.0(P4210057).jpg https://coralnet.ucsd.edu/image/2607170/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/vfh0ewklud.jpg?Signature=2fC2rpuGgII%2Br4%2FClphLafdvXWA%3D&Expires=1677876472&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-35.0(P4210058).jpg https://coralnet.ucsd.edu/image/2607171/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/p9y05g1ln0.jpg?Signature=zjZ%2FVYEYzF%2Ba%2FSoxhSukNJWsURk%3D&Expires=1677876473&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-36.0(P4210059).jpg https://coralnet.ucsd.edu/image/2607173/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/v28vt2ppuq.jpg?Signature=Bgw55ycYOVYdA%2BXxUy7UsFVbDjI%3D&Expires=1677876473&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-37.0(P4210060).jpg https://coralnet.ucsd.edu/image/2607174/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/2rm87k6rwl.jpg?Signature=Nb%2BlJQmj950EE7VzEGjoVeVLXC4%3D&Expires=1677876474&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-38.0(P4210061).jpg https://coralnet.ucsd.edu/image/2607175/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/d3ejzgi6v1.jpg?Signature=GKbkehJSEclNH%2FKgp6LAlx3ko0E%3D&Expires=1677876474&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-39.0(P4210062).jpg https://coralnet.ucsd.edu/image/2607177/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/jayvo0co7m.jpg?Signature=9Dyx4KU1aBkbsvju3x2diKtOidU%3D&Expires=1677876475&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-40.0(P4210063).jpg https://coralnet.ucsd.edu/image/2607178/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/4gzp13ti0l.jpg?Signature=Qv%2BbT01mNK%2Bfa3kBO6%2F3Umq7avg%3D&Expires=1677876475&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-41.0(P4210064).jpg https://coralnet.ucsd.edu/image/2607180/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/so36x401uw.jpg?Signature=ddtK4SVce6vYiJcfHiabXhDgwiw%3D&Expires=1677876476&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-42.0(P4210065).jpg https://coralnet.ucsd.edu/image/2607181/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/m49ez6bzzx.jpg?Signature=tfyucedyH3aiC9OmgqgYtwQHP8c%3D&Expires=1677876476&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-43.0(P4210066).jpg https://coralnet.ucsd.edu/image/2607183/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/xuwgskx1fv.jpg?Signature=PlL71Sp%2F2xOprZUKY1kMS5EOsjM%3D&Expires=1677876477&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-44.0(P4210067).jpg https://coralnet.ucsd.edu/image/2607184/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/rc9413eklx.jpg?Signature=2gfNA%2FJtZ%2BspQyV8FbPVgnmfT0Q%3D&Expires=1677876477&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-45.0(P4210068).jpg https://coralnet.ucsd.edu/image/2607186/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/fw9zibz1is.jpg?Signature=Fkn8rRyn48G6zowWZ%2F7Hu4RRalo%3D&Expires=1677876478&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-46.0(P4210069).jpg https://coralnet.ucsd.edu/image/2607187/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/6sbka2i73g.jpg?Signature=4%2FCqjBZbXAMK1AONv5LZNZEQDXg%3D&Expires=1677876478&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-47.0(P4210070).jpg https://coralnet.ucsd.edu/image/2607188/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/8bya6vlxs1.jpg?Signature=cff3iDcOmnPo1W2vnmgrysWwnUI%3D&Expires=1677876479&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-48.0(P4210071).jpg https://coralnet.ucsd.edu/image/2607190/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/p1gcvsi8ft.jpg?Signature=KOpnV71PYCttXZNIVeRAxYmocx0%3D&Expires=1677876479&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-49.0(P4210072).jpg https://coralnet.ucsd.edu/image/2607191/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/ohtzkpnm3i.jpg?Signature=ffFKwNuHTPGsxWJWR76bpPBqG5s%3D&Expires=1677876480&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T09-50.0(P4210073).jpg https://coralnet.ucsd.edu/image/2607193/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/qnk6xmx4dn.jpg?Signature=l2R7AbgdbS7jens4ehjs%2FdOM%2F98%3D&Expires=1677876480&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-01.0(P4210409).JPG https://coralnet.ucsd.edu/image/2597251/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/j69mp5lagn.JPG?Signature=W64Ge%2BQ08M13biDdBwYs1fGqTdE%3D&Expires=1677876481&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-02.0(P4210410).JPG https://coralnet.ucsd.edu/image/2597252/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/wuy3z1vmea.JPG?Signature=hwP2N5%2Fmhq8y2aym04wxicqxrX4%3D&Expires=1677876481&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-03.0(P4210412).JPG https://coralnet.ucsd.edu/image/2597253/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/s9yc5wpx93.JPG?Signature=ilxGKuBYG6zKpMHaXnqO8slxDXo%3D&Expires=1677876482&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-04.0(P4210413).JPG https://coralnet.ucsd.edu/image/2597254/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/1ut0l1ly32.JPG?Signature=qE%2FyfUDFTL7ZuWSGTw8X01EyFDY%3D&Expires=1677876482&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-05.0(P4210414).JPG https://coralnet.ucsd.edu/image/2597255/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/mnovt6r7o3.JPG?Signature=wVeJlw9Jeb3waK%2FYTH%2F8vgrQnsw%3D&Expires=1677876483&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-06.0(P4210415).JPG https://coralnet.ucsd.edu/image/2597256/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/48mhq8rdxp.JPG?Signature=WKqzVh2Ma%2FlZ0WDtD9tKZ4X8hLI%3D&Expires=1677876483&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-07.0(P4210417).JPG https://coralnet.ucsd.edu/image/2597257/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/3mjemcg1bq.JPG?Signature=9%2Bjtwk8p%2FHjOieKabSuzQlSH4Sk%3D&Expires=1677876484&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-08.0(P4210418).JPG https://coralnet.ucsd.edu/image/2597258/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/byhc0hzhxn.JPG?Signature=BdYOJu8Ro%2Fnt88qGnLQcIFDuJxY%3D&Expires=1677876484&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-09.0(P4210420).JPG https://coralnet.ucsd.edu/image/2597259/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/vjqs6wcwt1.JPG?Signature=HwISh3HybgtNTppHQopH2hBLGwU%3D&Expires=1677876485&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-10.0(P4210421).JPG https://coralnet.ucsd.edu/image/2597260/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/v2my02o3oy.JPG?Signature=hDoWesj9fOlUw1OuiE5SRlzxQOc%3D&Expires=1677876485&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-11.0(P4210423).JPG https://coralnet.ucsd.edu/image/2597261/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/1ljb5n3vms.JPG?Signature=slNUVy3wy0E%2BC2Eo4YU6kvE1x40%3D&Expires=1677876486&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-12.0(P4210424).JPG https://coralnet.ucsd.edu/image/2597262/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/g09avmku9d.JPG?Signature=RSb%2Bs5BbnodT%2B8NUPghFnuoaQcI%3D&Expires=1677876486&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-13.0(P4210427).JPG https://coralnet.ucsd.edu/image/2597263/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/3zn50z2df5.JPG?Signature=aoLOXaW9A8LhuHRtctLZcNa7nAM%3D&Expires=1677876487&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-14.0(P4210428).JPG https://coralnet.ucsd.edu/image/2597264/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/zysup7fqaa.JPG?Signature=RGWMy5%2FuikpiNlDpnDmiRqol7eY%3D&Expires=1677876487&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-15.0(P4210429).JPG https://coralnet.ucsd.edu/image/2597265/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/pqg08799jp.JPG?Signature=8ZpDmL7QA6z5Mgv1Pwnn%2B6N0QKw%3D&Expires=1677876488&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-16.0(P4210430).JPG https://coralnet.ucsd.edu/image/2597266/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/t44sfvx8f8.JPG?Signature=U03ecdd0c5JK4U1sUrIO%2FtjWfzM%3D&Expires=1677876488&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-17.0(P4210431).JPG https://coralnet.ucsd.edu/image/2597267/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/5w910v8n0l.JPG?Signature=PrUIs0ul8FrVZXZADv1FXIOo6lE%3D&Expires=1677876489&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-18.0(P4210433).JPG https://coralnet.ucsd.edu/image/2597268/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/yz86nfyhx2.JPG?Signature=IxThj%2FzOyiUaABq8rRiIeT17Rjk%3D&Expires=1677876489&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-19.0(P4210434).JPG https://coralnet.ucsd.edu/image/2597269/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/t3lkrgf9mt.JPG?Signature=ZHGo9%2BZXJrJ%2BUAza%2Fh722BKbEoA%3D&Expires=1677876490&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-20.0(P4210435).JPG https://coralnet.ucsd.edu/image/2597270/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/g5yhk715bs.JPG?Signature=t7oGbzfKKpI8MRRhF8kLvEY02Xk%3D&Expires=1677876490&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-21.0(P4210436).JPG https://coralnet.ucsd.edu/image/2597271/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/31ee338w4q.JPG?Signature=3A8TKi8iQZgO9K9M9Habs1oDN1Y%3D&Expires=1677876491&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-22.0(P4210437).JPG https://coralnet.ucsd.edu/image/2597272/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/asztk8ackh.JPG?Signature=oFlPQsZ3bsdjapxL5%2FG3jzPYGfc%3D&Expires=1677876491&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-23.0(P4210438).JPG https://coralnet.ucsd.edu/image/2597273/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/pis7ylucxg.JPG?Signature=0iYSh8VF0KOfmV22mkpJihlmbL4%3D&Expires=1677876492&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-24.0(P4210439).JPG https://coralnet.ucsd.edu/image/2597274/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/ta1siypd78.JPG?Signature=7mGQwCX6ltNPddKwpP47N7blytg%3D&Expires=1677876492&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-25.0(P4210440).JPG https://coralnet.ucsd.edu/image/2597275/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/21sjqnnlk2.JPG?Signature=j2ohiFSMefOHH%2BTTOovvU%2FW%2FR18%3D&Expires=1677876492&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-26.0(P4210441).JPG https://coralnet.ucsd.edu/image/2597276/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/kn3o37s81v.JPG?Signature=l1%2FOgszRFNs%2FEtd6wXjiuDc7tv8%3D&Expires=1677876493&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-27.0(P4210442).JPG https://coralnet.ucsd.edu/image/2597277/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/tyh4bw2tii.JPG?Signature=WfRmxvkV2J0YVrodq1mNy8QShPg%3D&Expires=1677876493&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-28.0(P4210443).JPG https://coralnet.ucsd.edu/image/2597278/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/n37pso0xya.JPG?Signature=djGUmQaiQZHb0KN5bt9a4grZMwM%3D&Expires=1677876494&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-29.0(P4210445).JPG https://coralnet.ucsd.edu/image/2597279/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/im31eybdjm.JPG?Signature=ftsiaDGgu41ED06CiM4DJtEeXko%3D&Expires=1677876495&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-30.0(P4210447).JPG https://coralnet.ucsd.edu/image/2597280/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/453grd7dvm.JPG?Signature=w44NyvpD86z1FUZXq0LyHUTOJ9w%3D&Expires=1677876495&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-31.0(P4210448).JPG https://coralnet.ucsd.edu/image/2597281/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/ej2fieup6c.JPG?Signature=EhNJnMzFOi2i78dAh8r4P%2BbaGZw%3D&Expires=1677876496&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-32.0(P4210450).JPG https://coralnet.ucsd.edu/image/2597282/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/vbj9hqxtdc.JPG?Signature=uOqtXswl8nmCxLOLkeysdaSH8Qs%3D&Expires=1677876496&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-33.0(P4210451).JPG https://coralnet.ucsd.edu/image/2597283/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/slx0bzfgtp.JPG?Signature=Z7ngaVO8qZgcC1FEsJYqnItcg5k%3D&Expires=1677876497&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-34.0(P4210453).JPG https://coralnet.ucsd.edu/image/2597284/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/rg3mhwcpk2.JPG?Signature=nwjwn3NTOX7ona%2FpVW7GzMFE%2FW8%3D&Expires=1677876497&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-35.0(P4210455).JPG https://coralnet.ucsd.edu/image/2597285/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/o5rv71xmug.JPG?Signature=6vYQbK3LP9oIRFzBWic3JUIY8y4%3D&Expires=1677876498&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-36.0(P4210456).JPG https://coralnet.ucsd.edu/image/2597286/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/dflpp33fgz.JPG?Signature=jC5Gl9n7VgKwUa7g%2BjuwZJ1ftgQ%3D&Expires=1677876498&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-37.0(P4210458).JPG https://coralnet.ucsd.edu/image/2597287/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/myqv1n4vuf.JPG?Signature=6379CxE4x4mjUxqRijmLiRCNUx8%3D&Expires=1677876499&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-38.0(P4210459).JPG https://coralnet.ucsd.edu/image/2597288/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/fd9c4t5gsh.JPG?Signature=1V%2BgoNvVduD0LN62azSWlPpRpzo%3D&Expires=1677876499&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-39.0(P4210461).JPG https://coralnet.ucsd.edu/image/2597289/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/bul9tdm2zd.JPG?Signature=ec2tP%2BjeCX%2Fz2rE%2BPznvk%2Fp7OxY%3D&Expires=1677876500&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-40.0(P4210462).JPG https://coralnet.ucsd.edu/image/2597290/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/2jv1uly8l0.JPG?Signature=08ZWnGzZIiSU4HCykqGCOmDZy3g%3D&Expires=1677876500&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-41.0(P4210463).JPG https://coralnet.ucsd.edu/image/2597291/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/bpfta3s31u.JPG?Signature=TbegUECz4AAj%2BfYFf5vy3cNxyBw%3D&Expires=1677876500&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-42.0(P4210465).JPG https://coralnet.ucsd.edu/image/2597292/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/p647oycfyf.JPG?Signature=iESmz5Y5%2FZcJvGvSqUs5hje89bo%3D&Expires=1677876501&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-43.0(P4210467).JPG https://coralnet.ucsd.edu/image/2597293/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/nbf7n5yvex.JPG?Signature=H4fDGaHQCqaoV98xU4Ci2%2BrB%2BSE%3D&Expires=1677876501&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-44.0(P4210468).JPG https://coralnet.ucsd.edu/image/2597294/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/go4nflnnsk.JPG?Signature=9QR3Ni6Dkr7yx1xhQYcVKGUCflI%3D&Expires=1677876502&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-45.0(P4210469).JPG https://coralnet.ucsd.edu/image/2597295/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/cjm9rov64m.JPG?Signature=RjCKuqXGjO7XOwrYa6JiiG3MEm0%3D&Expires=1677876502&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-46.0(P4210470).JPG https://coralnet.ucsd.edu/image/2597296/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/fthzhyomzg.JPG?Signature=0Z%2FsPwkvvNQOsxDstvpeH%2BRc0uU%3D&Expires=1677876503&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-47.0(P4210472).JPG https://coralnet.ucsd.edu/image/2597297/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/c6jvonptba.JPG?Signature=m4CXLYxCS%2F0NcNaORwJfDsJSpYk%3D&Expires=1677876503&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-48.0(P4210474).JPG https://coralnet.ucsd.edu/image/2597298/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/435ge6hozy.JPG?Signature=TzbIzlPBx1EhXsWrh%2BqzFbd24Rc%3D&Expires=1677876504&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-49.0(P4210476).JPG https://coralnet.ucsd.edu/image/2597299/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/wd8fx6ov0g.JPG?Signature=3LtGYZ%2FNsheRQfLLzEhYXjUnNtg%3D&Expires=1677876504&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T10-50.0(P4210477).JPG https://coralnet.ucsd.edu/image/2597300/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/dtizppxc26.JPG?Signature=4jiHN%2BEPmwOGqjd3OzOv3k96nSk%3D&Expires=1677876505&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-01.0(P4210084).JPG https://coralnet.ucsd.edu/image/2597301/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/cl0frfswsp.JPG?Signature=2lylvdjzgTzaZ5QY%2B0AtYnu3shM%3D&Expires=1677876505&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-02.0(P4210086).JPG https://coralnet.ucsd.edu/image/2597302/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/t4gbmoc2y6.JPG?Signature=%2BJC5jw%2FjmhPJhMsbK6swKJrOnCE%3D&Expires=1677876506&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-03.0(P4210087).JPG https://coralnet.ucsd.edu/image/2597303/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/yylefw369h.JPG?Signature=KQ1HWV2hhvi3CGXXaQ5CbvOtSPQ%3D&Expires=1677876507&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-04.0(P4210088).JPG https://coralnet.ucsd.edu/image/2597304/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/6gun0cafyy.JPG?Signature=oXlgx9Ijf9JNc5fHMXzXVtIttlw%3D&Expires=1677876507&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-05.0(P4210089).JPG https://coralnet.ucsd.edu/image/2597305/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/s77uosy4y6.JPG?Signature=HE2cnVQzdubHWhZ0vXpG%2B4Lm77M%3D&Expires=1677876507&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-06.0(P4210090).JPG https://coralnet.ucsd.edu/image/2597306/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/wloi85vh6q.JPG?Signature=XmwXlDRLc4E0A39S2ntssLIJuYk%3D&Expires=1677876508&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-07.0(P4210091).JPG https://coralnet.ucsd.edu/image/2597307/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/njz76adl1p.JPG?Signature=e224sy3YSKkhbsaLas2Dme0KyXQ%3D&Expires=1677876509&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-08.0(P4210093).JPG https://coralnet.ucsd.edu/image/2597308/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/fps856b1u2.JPG?Signature=O1YyOg1ZKVxPfVqkbTKJMRT41qU%3D&Expires=1677876509&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-09.0(P4210094).JPG https://coralnet.ucsd.edu/image/2597309/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/acq6hdkc5v.JPG?Signature=vSKf7EPxNJltDsUxz4O4qNfU9vw%3D&Expires=1677876510&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-10.0(P4210095).JPG https://coralnet.ucsd.edu/image/2597310/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/fhy0sp4cpe.JPG?Signature=FMLP9PUwQ8TEC2B65M6xt422%2BOc%3D&Expires=1677876511&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-11.0(P4210096).JPG https://coralnet.ucsd.edu/image/2597311/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/1wy7uk3dyv.JPG?Signature=BEBJVJNMJfcyzrCEInVdXiX%2BE3U%3D&Expires=1677876511&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-12.0(P4210097).JPG https://coralnet.ucsd.edu/image/2597312/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/ze5mhgra1e.JPG?Signature=ZOElwJMO6IXSap9gLvxZuh4gvjk%3D&Expires=1677876512&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-13.0(P4210098).JPG https://coralnet.ucsd.edu/image/2597313/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/fncd39c7e0.JPG?Signature=KV45qSepyGVKZj4MLt1WmevIBXo%3D&Expires=1677876512&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-14.0(P4210099).JPG https://coralnet.ucsd.edu/image/2597314/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/sm7488ttcf.JPG?Signature=GULOGmamWKS10eHDhDGnfZPmtSI%3D&Expires=1677876513&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-15.0(P4210100).JPG https://coralnet.ucsd.edu/image/2597315/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/i677gv30p0.JPG?Signature=s28GvZxF%2F%2B1s2D1VfseLu0QNi9A%3D&Expires=1677876513&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-16.0(P4210101).JPG https://coralnet.ucsd.edu/image/2597316/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/86j8o5xfki.JPG?Signature=77jWtyzrQGAyfXZ3DvnlQD0cPgo%3D&Expires=1677876514&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-17.0(P4210102).JPG https://coralnet.ucsd.edu/image/2597317/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/85nxcmvm1a.JPG?Signature=jQTTdZKceVIvJHrYrFhBQaHhjbE%3D&Expires=1677876514&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-18.0(P4210103).JPG https://coralnet.ucsd.edu/image/2597318/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/0m6jz7gb1n.JPG?Signature=K%2BqSyPqxwYZFm3lWoXbNptpHo1o%3D&Expires=1677876515&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-19.0(P4210104).JPG https://coralnet.ucsd.edu/image/2597319/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/01kumff928.JPG?Signature=HzzVQ8%2B5pAxbzIC2ihk6qin%2FlVc%3D&Expires=1677876515&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-20.0(P4210105).JPG https://coralnet.ucsd.edu/image/2597320/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/klwwvgny8o.JPG?Signature=7pmpJY%2Bd2VDgxQWnXpYUJlbz6po%3D&Expires=1677876516&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-21.0(P4210106).JPG https://coralnet.ucsd.edu/image/2597321/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/ztfoy14d9f.JPG?Signature=YKzXw%2F7RA7SK8ODTlu8MQkaGYA0%3D&Expires=1677876516&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-22.0(P4210107).JPG https://coralnet.ucsd.edu/image/2597322/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/d2wc88v4x3.JPG?Signature=IeuGa3vUr2hfBQuauLVYtxWFdC4%3D&Expires=1677876517&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-23.0(P4210108).JPG https://coralnet.ucsd.edu/image/2597323/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/1rv6unebdu.JPG?Signature=2XEWbi%2F2FAXX%2FVe2%2BSFhPWsJg2s%3D&Expires=1677876517&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-24.0(P4210109).JPG https://coralnet.ucsd.edu/image/2597324/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/r8p2ho26wm.JPG?Signature=RCktXu2zXvbLhoyBgMmPjjVbbpc%3D&Expires=1677876518&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-25.0(P4210110).JPG https://coralnet.ucsd.edu/image/2597325/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/vys0246fsm.JPG?Signature=2PvHfnkjH8Oo061oGREGBxvSvJE%3D&Expires=1677876518&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-26.0(P4210111).JPG https://coralnet.ucsd.edu/image/2597326/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/rwkkizgn98.JPG?Signature=GWRl44u39GWg3z1SELEWvKizLqA%3D&Expires=1677876519&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-27.0(P4210112).JPG https://coralnet.ucsd.edu/image/2597327/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/ping7u0nqo.JPG?Signature=M3NfUZLuUlOWlkK1LGnp0gyuTGs%3D&Expires=1677876519&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-28.0(P4210113).JPG https://coralnet.ucsd.edu/image/2597328/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/o90vr95kry.JPG?Signature=MyOuWkLEsKE%2BGiZcPQ2dgkUWQHU%3D&Expires=1677876520&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-29.0(P4210114).JPG https://coralnet.ucsd.edu/image/2597329/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/k9fop5ve92.JPG?Signature=N56Gxp3TtQmBZ5v6DhDtlGMvnz0%3D&Expires=1677876520&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-30.0(P4210115).JPG https://coralnet.ucsd.edu/image/2597330/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/zkgsidoai8.JPG?Signature=cocANhTAkyUebAwClleR3ka7Re8%3D&Expires=1677876521&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-31.0(P4210116).JPG https://coralnet.ucsd.edu/image/2597331/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/udcjgkurns.JPG?Signature=Gp23jswDd4cQBfTVsP5mYlJWblU%3D&Expires=1677876521&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-32.0(P4210117).JPG https://coralnet.ucsd.edu/image/2597332/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/9ews1coaw0.JPG?Signature=GjjNMXPT1tTA5hLDXWTnIzRSSXE%3D&Expires=1677876522&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-33.0(P4210118).JPG https://coralnet.ucsd.edu/image/2597333/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/4mjkbc6tus.JPG?Signature=YP9ljAhtWJpR%2B80ZAk7C4ywop3s%3D&Expires=1677876522&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# 2022-04-21-AGAT-T13-34.0(P4210119).JPG https://coralnet.ucsd.edu/image/2597334/view/ https://coralnet-production.s3.amazonaws.com:443/media/images/de966qjl6l.JPG?Signature=PNS0sC%2FJiaeQ%2FZ9HsG6%2BPUUKkRA%3D&Expires=1677876523&AWSAccessKeyId=AKIAYVKEQ3B4DIOYONO3
# ...
# File downloaded:  ./3361/images/2022-06-25-ASAN-T11-37 P6250038.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T03-45.0(P4281625).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-13 P6250116.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-21.0(P4271152).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-01 P8140314.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T02-47.0(P4271354).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T11-38 P6250039.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T03-46.0(P4281626).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-14 P6250117.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-22.0(P4271153).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T02-48.0(P4271356).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-02 P8140315.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T03-47.0(P4281627).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T11-39 P6250041.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-23.0(P4271155).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-15 P6250118.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T02-49.0(P4271359).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-03 P8140316.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T03-48.0(P4281629).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T11-40 P6250042.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-24.0(P4271156).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-16 P6250119.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T02-50.0(P4271363).JPG
# File downloaded:  ./3361/images/2022-04-28-ASAN-T03-49.0(P4281631).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-04 P8140317.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T11-41 P6250043.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-25.0(P4271159).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-01.0(P4271386).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-17 P6250120.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T03-50.0(P4281632).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-05 P8140318.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T11-42 P6250044.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-26.0(P4271160).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-02.0(P4271387).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-18 P6250121.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-01.0(P4282198).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-06 P8140319.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T11-43 P6250045.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-27.0(P4271161).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-03.0(P4271388).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-19 P6250122.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-03.0(P4282199).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-28.0(P4271163).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T11-44 P6250046.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-07 P8140320.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-04.0(P4271389).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-20 P6250123.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-04.0(P4282200).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-29.0(P4271164).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-08 P8140321.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T11-45 P6250047.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-05.0(P4271390).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-21 P6250124.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-05.0(P4282201).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-30.0(P4271166).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-09 P8140322.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T11-46 P6250048.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-06.0(P4271391).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-22 P6250125.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-06.0(P4282202).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-31.0(P4271168).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T11-47 P6250049.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-10 P8140323.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-07.0(P4271392).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-23 P6250126.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T11-48 P6250050.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-07.0(P4282203).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-32.0(P4271170).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-11 P8140324.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-08.0(P4271393).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-24 P6250127.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T11-49 P6250051.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-08.0(P4282204).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-33.0(P4271171).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-12 P8140325.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-09.0(P4271394).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-25 P6250128.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-34.0(P4271173).JPG
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-09.0(P4282205).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T11-50 P6250052.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-10.0(P4271395).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-13 P8140326.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-26 P6250129.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-35.0(P4271175).JPG
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-10.0(P4282206).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-01 P6250155.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-11.0(P4271396).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-14 P8140327.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-27 P6250130.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-36.0(P4271176).JPG
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-11.0(P4282207).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-02 P6250156.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-12.0(P4271397).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-15 P8140328.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-37.0(P4271179).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-28 P6250131.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-12.0(P4282208).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-13.0(P4271398).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-03 P6250157.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-38.0(P4271180).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-16 P8140329.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-29 P6250132.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-13.0(P4282209).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-14.0(P4271399).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-04 P6250158.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-39.0(P4271181).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-17 P8140330.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-30 P6250133.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-14.0(P4282211).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-05 P6250159.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-15.0(P4271400).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-40.0(P4271182).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-18 P8140331.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-31 P6250134.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-15.0(P4282212).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-41.0(P4271183).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-06 P6250160.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-16.0(P4271402).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-19 P8140332.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-17.0(P4271403).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-42.0(P4271184).JPG
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-16.0(P4282213).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-32 P6250135.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-07 P6250161.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-20 P8140333.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-18.0(P4271404).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-43.0(P4271185).JPG
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-17.0(P4282214).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-08 P6250162.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-33 P6250136.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-21 P8140334.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-19.0(P4271405).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-44.0(P4271186).JPG
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-18.0(P4282215).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-09 P6250163.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-34 P6250137.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-22 P8140335.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-45.0(P4271187).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-20.0(P4271406).JPG
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-19.0(P4282217).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-10 P6250164.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-35 P6250138.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T04-21.0(P4271407).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-46.0(P4271188).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-23 P8140336.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-20.0(P4282218).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-11 P6250165.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-36 P6250139.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-24 P8140337.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-21.0(P4282219).JPG
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-47.0(P4271189).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-12 P6250166.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-37 P6250140.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-48.0(P4271190).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-25 P8140338.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-22.0(P4282220).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-13 P6250167.jpg
# File downloaded:  ./3361/images/2022-04-27-ASAN-T13-49.0(P4271191).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-26 P8140339.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-38 P6250141.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-23.0(P4282221).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-14 P6250168.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-39 P6250142.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-24.0(P4282222).JPG
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-27 P8140340.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-15 P6250169.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-25.0(P4282223).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-40 P6250143.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-28 P8140341.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-16 P6250170.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-26.0(P4282224).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-41 P6250144.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-29 P8140342.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-27.0(P4282225).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-42 P6250145.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-30 P8140343.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-28.0(P4282226).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-43 P6250146.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-31 P8140344.jpg
# File downloaded:  ./3361/images/2022-04-28-ASAN-T26-29.0(P4282228).JPG
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-44 P6250147.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-32 P8140345.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-17 P6250171.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-45 P6250148.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-33 P8140346.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-18 P6250172.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-46 P6250149.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-34 P8140347.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-19 P6250173.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-47 P6250150.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-35 P8140348.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-20 P6250174.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-48 P6250151.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-36 P8140349.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-21 P6250175.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-49 P6250152.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-37 P8140350.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-22 P6250176.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T01-50 P6250153.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-38 P8140351.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-23 P6250177.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T07-01 P6250054.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-39 P8140352.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-24 P6250178.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T07-02 P6250055.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-40 P8140353.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-25 P6250179.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T07-03 P6250056.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-26 P6250180.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-41 P8140354.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T07-04 P6250057.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-27 P6250181.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-42 P8140355.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T07-05 P6250058.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-28 P6250182.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-43 P8140356.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T07-06 P6250059.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-44 P8140357.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-29 P6250183.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T07-07 P6250060.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-45 P8140358.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-30 P6250184.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-46 P8140359.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-31 P6250185.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-47 P8140360.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-32 P6250186.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-48 P8140361.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-33 P6250187.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-49 P8140362.jpg
# File downloaded:  ./3361/images/2022-06-25-ASAN-T18-34 P6250188.jpg
# File downloaded:  ./3361/images/2022-08-14-ASAN-T16-50 P8140363.jpg
# Done.
