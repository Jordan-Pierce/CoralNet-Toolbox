# %%
import os
import glob

import pandas as pd
import matplotlib.pyplot as plt
from skimage.io import imread, imsave

# %%
def crop_patch(image, y, x, size=112):
    """Given an image, and a Y, X location, this function will extract the patch. 
        Default patch size is 112 x 112"""

    patch = image[abs(size - y) : abs(size + y), abs(size - x) : abs(size + x), :]
    
    return patch


def check_dimensions(image, y, x, size=224):
    """Before a patch is extracted from an image, check to make sure that it will not
        extend pass the dimensions of the image."""
    
    # Get the dimensions of the image first, then check to make sure the patch that would be
    # extacted doesn't over-extend the boundaries of the image.
    height, width = image.shape[0:2]
    
    if(x + (size//2) > width or x - (size//2) < 0 or y + (size//2) > height or y - (size//2) < 0):
        return False
    else:
        return True
    
    
def extract_patches_from_point(image, x, y):
    """Take in the image and a point xy, check that the would-be patch does not exceed
        the border of the image, and crop the patch"""
    
    # Filter out points that exceed the extent of the image
    if check_dimensions(image, y, x):
        
        # Extract the patches 
        patch = crop_patch(image, y, x)
        
    else:
        patch = None
        
    return patch

# %%
data_root = "/mnt/batch/tasks/shared/LS_root/mounts/clusters/nccos-vs-jordan-ml/code/Users/jordan.pierce/Data/Guam_Saipan/"
image_path = data_root + "Images/"
label_path = data_root + "CNet_Annotations.csv"
patch_path = data_root + "Patches/

df = pd.read_csv(label_path)

imported_df = df[df['Annotator'] == 'Imported']
robot_df = df[df['Annotator'] == 'robot']

# %%
imported_df['Label'].value_counts().plot(kind='bar'); plt.show()
imported_df['Name'].unique().shape
# Out:
# (79,)

# %%
updated_imported_df = []

for i, r in imported_df.iterrows():
    
    image = image_path + r['Name']
    img = imread(image)
    patch = extract_path(img, r['Row'], ['Column'])
    
    patch_name = r["Name"].split(".")[0] + "_" + r['Label'] + "_" + r['Row'] + "_" + r["Column"] + ".png"
    patch_name = patch_path + patch_name
    
    imsave(fname=patch_name, arr=patch)
    
    r['Patch_Name'] = patch_name
    
    updated_imported_df.append(r)
    
updated_imported_df = pd.DataFrame(updated_imported_df)
updated_imported_df.to_csv(data_root + "Updated_CNet_Annotations.csv")
# Out:
#                           Name   Row  Column    Label Annotator  \
# 0           AA257_SA704589.jpg   379    2035    Mu_Ba  Imported
# 1           AA257_SA704589.jpg   474    2093    Mu_Ba  Imported
# 2           AA257_SA704589.jpg   717    2061    Mu_Ba  Imported
# 3           AA257_SA704589.jpg  1001    1645    Mu_Ba  Imported
# 4           AA257_SA704589.jpg   163    2626    Mu_Ba  Imported
# ...                        ...   ...     ...      ...       ...
# 78182  Test_GV111_SA706463.jpg  2125    3818    UDC_H     robot
# 78183  Test_GV111_SA706463.jpg  2125    4449  LC_Encr     robot
# 78184  Test_GV111_SA706463.jpg  2125    5080    Sa_TA     robot
# 78185  Test_GV111_SA706463.jpg  2125    5711   LC_Por     robot
# 78186  Test_GV111_SA706463.jpg  2125    6342    UDC_H     robot
#
#                   Date annotated Machine suggestion 1  Machine confidence 1  \
# 0      2023-02-07 19:24:26+00:00                  NaN                   NaN
# ...
